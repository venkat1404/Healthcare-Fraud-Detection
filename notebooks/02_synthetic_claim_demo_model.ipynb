# %% [markdown]
# # 02 Synthetic Claim Demo Model
#
# This notebook runs the secondary synthetic claim-level fraud model used for demo and comparison purposes.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src.data_processing import infer_target_column, load_synthetic_dataset
from src.feature_engineering import prepare_synthetic_claim_dataset
from src.train_model import train_synthetic_demo_model

# %%
synthetic_df = load_synthetic_dataset()
target_column = infer_target_column(synthetic_df)
X, y = prepare_synthetic_claim_dataset(synthetic_df, target_column)
X.head()

# %%
y.value_counts(normalize=True)

# %%
bundle = train_synthetic_demo_model()
bundle['model_name'], bundle['threshold']

# %% [markdown]
# ## Why This Dataset Is Secondary
#
# The synthetic dataset is useful for a polished demo and easier manual input, but it should not be treated as the primary business evidence because it is not real insurer operations data.
